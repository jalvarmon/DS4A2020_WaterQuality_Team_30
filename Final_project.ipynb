# %% [markdown]
# # Water quality project

# %%
import pandas as pd
import numpy as np

# %%
# Load data and preview
df_chemicals = pd.read_csv("datasets/chemicals.csv")
df_chemicals.head()
#pd.options.display.maxcolumns = 1
# Out:
#                                cws_name chemical_species  \
# 0  CALIFORNIA WATER SERVICE - LIVERMORE          Uranium
# 1                     CITY OF LIVERMORE          Uranium
# 2                    CITY OF PLEASANTON          Uranium
# 3    DUBLIN SAN RAMON SERVICES DISTRICT          Uranium
# 4    NORRIS CANYON PROPERTY OWNERS ASSN          Uranium
#
#         contaminant_level   county     pws_id  pop_served       state  \
# 0  Less than or equal MCL  Alameda  CA0110003       57200  California
# 1  Less than or equal MCL  Alameda  CA0110011       26400  California
# 2  Less than or equal MCL  Alameda  CA0110008       70600  California
# 3  Less than or equal MCL  Alameda  CA0110009       72500  California
# 4  Less than or equal MCL  Alameda  CA0103040         100  California
#
#   unit_measurement  value  year  fips  state_fips
# 0     micrograms/L   1.54  2000  6001           6
# 1     micrograms/L   1.64  2000  6001           6
# ...

# %%
df_droughts = pd.read_csv("datasets/droughts.csv")
#df_droughts['year'].unique()
df_droughts.tail()
# Out:
#           fips         county state   none     d0   d1   d2   d3   d4  \
# 1345537  56045  Weston County    WY  78.20  21.80  0.0  0.0  0.0  0.0
# 1345538  56045  Weston County    WY  78.20  21.80  0.0  0.0  0.0  0.0
# 1345539  56045  Weston County    WY  78.20  21.80  0.0  0.0  0.0  0.0
# 1345540  56045  Weston County    WY  78.20  21.80  0.0  0.0  0.0  0.0
# 1345541  56045  Weston County    WY  76.84  23.16  0.0  0.0  0.0  0.0
#
#         valid_start   valid_end
# 1345537  2010-01-26  2010-02-01
# 1345538  2010-01-19  2010-01-25
# 1345539  2010-01-12  2010-01-18
# 1345540  2010-01-05  2010-01-11
# 1345541  2009-12-29  2010-01-04

# %%
df_education = pd.read_csv("datasets/education_attainment.csv", encoding='latin-1')
#df_droughts['year'].unique()
df_education.head()
# Out:
#    fips state          county  year  less_than_hs  hs_diploma  \
# 0     0    US   United States  1970    52373312.0  34158051.0
# 1  1000    AL         Alabama  1970     1062306.0    468269.0
# 2  1001    AL  Autauga County  1970        6611.0      3757.0
# 3  1003    AL  Baldwin County  1970       18726.0      8426.0
# 4  1005    AL  Barbour County  1970        8120.0      2242.0
#
#    some_college_or_associates  college_bachelors_or_higher  pct_less_than_hs  \
# 0                  11650730.0                   11717266.0              47.7
# 1                    136287.0                     141936.0              58.7
# 2                       933.0                        767.0              54.8
# 3                      2334.0                       2038.0              59.4
# 4                       581.0                        861.0              68.8
#
#    pct_hs_diploma  pct_college_or_associates  pct_college_bachelors_or_higher  \
# ...

# %%
df_earnings = pd.read_csv("datasets/earnings.csv", encoding='latin-1')
df_earnings.head()
# Out:
#            geo_id  fips                   county  total_med  \
# 0  0500000US01001  1001  Autauga County, Alabama      31811
# 1  0500000US01003  1003  Baldwin County, Alabama      30099
# 2  0500000US01005  1005  Barbour County, Alabama      23504
# 3  0500000US01007  1007     Bibb County, Alabama      30453
# 4  0500000US01009  1009   Blount County, Alabama      30739
#
#   total_agri_fish_mine agri_fish_hunt mining_quarrying_oilgas_extract  \
# 0                31793          31957                           22357
# 1                33173          27342                           80938
# 2                16167          14464                           27500
# 3                45237          46064                           34406
# 4                26909          25610                           54375
#
#   construction manufacturing wholesale_trade  ...  admin_sup  \
# 0        30347         44452           38203  ...      31250
# ...

# %%
df_ind_occupation = pd.read_csv("datasets/industry_occupation.csv")
df_ind_occupation.tail()
# Out:
#               geo_id   fips            county state  year  total_employed  \
# 4930  0500000US55133  55133   Waukesha County    WI  2016        212586.0
# 4931  0500000US55139  55139  Winnebago County    WI  2016         87738.0
# 4932  0500000US55141  55141       Wood County    WI  2016         37953.0
# 4933  0500000US56021  56021    Laramie County    WY  2016         46134.0
# 4934  0500000US56025  56025    Natrona County    WY  2016         41690.0
#
#       agriculture  construction  manufacturing  wholesale_trade  retail_trade  \
# 4930       1336.0       12162.0        36588.0           9064.0       23821.0
# 4931        471.0        3968.0        21896.0           2906.0       10210.0
# 4932       1664.0        2325.0         6945.0            825.0        3306.0
# 4933       1553.0        3430.0         2180.0            417.0        5372.0
# 4934       3011.0        2895.0         2719.0           1425.0        4295.0
#
# ...

# %%
df_ind_occupation = pd.read_csv("datasets/industry_occupation.csv", encoding='latin-1')
df_ind_occupation.tail()
# Out:
#               geo_id   fips            county state  year  total_employed  \
# 4930  0500000US55133  55133   Waukesha County    WI  2016        212586.0
# 4931  0500000US55139  55139  Winnebago County    WI  2016         87738.0
# 4932  0500000US55141  55141       Wood County    WI  2016         37953.0
# 4933  0500000US56021  56021    Laramie County    WY  2016         46134.0
# 4934  0500000US56025  56025    Natrona County    WY  2016         41690.0
#
#       agriculture  construction  manufacturing  wholesale_trade  retail_trade  \
# 4930       1336.0       12162.0        36588.0           9064.0       23821.0
# 4931        471.0        3968.0        21896.0           2906.0       10210.0
# 4932       1664.0        2325.0         6945.0            825.0        3306.0
# 4933       1553.0        3430.0         2180.0            417.0        5372.0
# 4934       3011.0        2895.0         2719.0           1425.0        4295.0
#
# ...

# %%
df_ind_occupation = pd.read_csv("datasets/water_usage.csv")
df_ind_occupation.tail()
# Out:
#      state  state_fips            county  county_fips   fips  year  \
# 3219    PR          72    Yabucoa County          151  72151  2010
# 3220    PR          72      Yauco County          153  72153  2010
# 3221    VI          78   St Croix County           10  78010  2010
# 3222    VI          78    St John County           20  78020  2010
# 3223    VI          78  St Thomas County           30  78030  2010
#
#       population  pub_sup_1  pub_sup_2  pub_sup_3  ...  thermoelectric_30  \
# 3219      37.941     18.190     19.751     37.941  ...                0.0
# 3220      42.043     17.013     25.030     42.043  ...                0.0
# 3221      50.601        NaN        NaN     39.320  ...                0.0
# 3222       4.170        NaN        NaN      1.770  ...                0.0
# 3223      51.634        NaN        NaN     27.922  ...                0.0
#
#       gro_wat_1  gro_wat_2  gro_wat_3  surf_wat_1  surf_wat_2  surf_wat_3  \
# ...
